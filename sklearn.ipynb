# %%
import csv
import pandas as pd
import statsmodels.formula.api as smf
from sklearn import feature_selection

dataset = 'https://gist.githubusercontent.com/tijptjik/03305bc2d75cda183439/raw/5d0acdb9dc7a5b39d057c837ec650dd09c4e9b36/cars1920.csv'
dataset = pd.read_csv(dataset)



m = smf.ols('speed ~ dist', data=dataset)
results = m.fit()
print results.summary()


lm = linear_model.LinearRegression()
cars = dataset
print cars.columns

print feature_selection.f_regression(cars[['speed']], cars[['dist']])

def f_regression_feature_selection(input, response):    
    feature_selection.univariate_selection.f_regression(input, response)
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                  speed   R-squared:                       0.651
# Model:                            OLS   Adj. R-squared:                  0.644
# Method:                 Least Squares   F-statistic:                     89.57
# Date:                Mon, 06 Oct 2014   Prob (F-statistic):           1.49e-12
# Time:                        18:30:11   Log-Likelihood:                -127.39
# No. Observations:                  50   AIC:                             258.8
# Df Residuals:                      48   BIC:                             262.6
# Df Model:                           1
# ...
#                  coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------
# Intercept      8.2839      0.874      9.474      0.000         6.526    10.042
# dist           0.1656      0.017      9.464      0.000         0.130     0.201
# ...

# %% [markdown]
# homework

# %%
import csv
import pandas as pd
import statsmodels.formula.api as smf
from sklearn import feature_selection

#4 , 5 features to work from, using loop to see R2
dataset = 'https://raw.githubusercontent.com/TeachingDataScience/data-science-course/forstudentviewing/09_linear_regression/data/day.csv'
dataset = pd.read_csv(dataset)
dataset.head()
# Out:
#    instant      dteday  season  yr  mnth  holiday  weekday  workingday  \
# 0        1  2011-01-01       1   0     1        0        6           0
# 1        2  2011-01-02       1   0     1        0        0           0
# 2        3  2011-01-03       1   0     1        0        1           1
# 3        4  2011-01-04       1   0     1        0        2           1
# 4        5  2011-01-05       1   0     1        0        3           1
#
#    weathersit      temp     atemp       hum  windspeed  casual  registered  \
# 0           2  0.344167  0.363625  0.805833   0.160446     331         654
# 1           2  0.363478  0.353739  0.696087   0.248539     131         670
# 2           1  0.196364  0.189405  0.437273   0.248309     120        1229
# 3           1  0.200000  0.212122  0.590435   0.160296     108        1454
# 4           1  0.226957  0.229270  0.436957   0.186900      82        1518
#
#     cnt
# 0   985
# 1   801
# 2  1349
# 3  1562
# 4  1600
